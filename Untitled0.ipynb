# %%
# !nvidia-smi
# Out:
# Wed Oct 11 10:08:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolov8
# Out:
# /content/drive/MyDrive/yolov8

# %%
# !ls
# Out:
# data  data.yaml  Untitled0.ipynb

# %%
# %cd /content/drive/MyDrive/yolov8
# Out:
# /content/drive/MyDrive/yolov8

# %% [markdown]
# **TRAIN**

# %%
# %cd /content/drive/MyDrive/yolov8

# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/yolov8
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train8
# Out:
# args.yaml					     train_batch2.jpg
# confusion_matrix.png				     train_batch435.jpg
# events.out.tfevents.1689765913.e4f8ce39de20.10681.0  train_batch436.jpg
# F1_curve.png					     train_batch437.jpg
# P_curve.png					     val_batch0_labels.jpg
# PR_curve.png					     val_batch0_pred.jpg
# R_curve.png					     val_batch1_labels.jpg
# results.csv					     val_batch1_pred.jpg
# results.png					     val_batch2_labels.jpg
# train_batch0.jpg				     val_batch2_pred.jpg
# train_batch1.jpg				     weights

# %%
Image(filename='runs/detect/train8/confusion_matrix.png',width=600)

# %%
Image(filename='runs/detect/train8/results.png',width=600)

# %%
Image(filename='runs/detect/train8/val_batch0_pred.jpg',width=600)

# %% [markdown]
# VALIDATE

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/yolov8/runs/detect/train8/weights/best.pt data=/content/drive/MyDrive/yolov8/data.yaml
# Out:
# 2023-07-19 12:00:27.167515: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 12:00:28.045982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8/data/valid/labels.cache... 130 images, 0 backgrounds, 0 corrupt: 100% 130/130 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:08<00:00,  1.00it/s]
#                    all        130        217      0.924      0.931      0.958      0.756
# ...

# %% [markdown]
# INFERENCE

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/runs/detect/train8/weights/best.pt save_txt=True conf=0.5 save_conf=True source=/content/drive/MyDrive/yolov8/data/test/video/elewdg.mp4 save=True
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
/content/drive/MyDrive/yolov8/runs
/content/runs

# %% [markdown]
# results

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict/*.mp4')[:7]:
  display(Image(filename=image_path,width=640))
  print('\n')
